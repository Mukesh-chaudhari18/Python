# %% [markdown]
# # Python Practice Questions Workbook
#
# This workbook contains beginner-friendly Python practice questions based on:
#
# - Data Types
# - Input Function
# - Conditional Statements
# - Loops
# - Functions
# - User Defined Functions
# - Lambda Functions
#
# Solve all questions by writing code below each question.

# %% [markdown]
# # Data Types Questions

# %% [markdown]
# ## Question 1
#
# Create variables for name, age, salary, and is_student. Print their data types.

# %%
# Write your code here

# %% [markdown]
# ## Question 2
#
# Convert integer to float and print both values.

# %%
# Write your code here

# %% [markdown]
# ## Question 3
#
# Take a number as string input and convert it into integer.

# %%
# Write your code here

# %% [markdown]
# ## Question 4
#
# Create a list, tuple, set, and dictionary and print their types.

# %%
# Write your code here

# %% [markdown]
# ## Question 5
#
# Write a program to swap two variables.

# %%
# Write your code here

# %% [markdown]
# # Input Function Questions

# %% [markdown]
# ## Question 6
#
# Take student name and marks as input and print them.

# %%
# Write your code here

# %% [markdown]
# ## Question 7
#
# Take two numbers from user and print their sum.

# %%
# Write your code here

# %% [markdown]
# ## Question 8
#
# Take length and breadth from user and calculate area of rectangle.

# %%
# Write your code here

# %% [markdown]
# ## Question 9
#
# Take temperature input in Celsius and convert to Fahrenheit.

# %%
# Write your code here

# %% [markdown]
# ## Question 10
#
# Take username and password input and print login details.

# %%
# Write your code here

# %% [markdown]
# # Conditional Statements Questions

# %% [markdown]
# ## Question 11
#
# Check whether a number is even or odd.

# %%
# Write your code here

# %% [markdown]
# ## Question 12
#
# Check whether a person is eligible to vote.

# %%
# Write your code here

# %% [markdown]
# ## Question 13
#
# Find greatest among two numbers.

# %%
# Write your code here

# %% [markdown]
# ## Question 14
#
# Find greatest among three numbers.

# %%
# Write your code here

# %% [markdown]
# ## Question 15
#
# Create grading system using marks.

# %%
# Write your code here

# %% [markdown]
# ## Question 16
#
# Check whether a year is leap year or not.

# %%
# Write your code here

# %% [markdown]
# ## Question 17
#
# Check whether number is positive, negative, or zero.

# %%
# Write your code here

# %% [markdown]
# ## Question 18
#
# Create simple ATM withdrawal condition program.

# %%
# Write your code here

# %% [markdown]
# # Loop Questions

# %% [markdown]
# ## Question 19
#
# Print numbers from 1 to 10 using for loop.

# %%
# Write your code here

# %% [markdown]
# ## Question 20
#
# Print numbers from 10 to 1 using while loop.

# %%
# Write your code here

# %% [markdown]
# ## Question 21
#
# Print even numbers from 1 to 50.

# %%
# Write your code here

# %% [markdown]
# ## Question 22
#
# Print multiplication table of a number.

# %%
# Write your code here

# %% [markdown]
# ## Question 23
#
# Find sum of first 10 natural numbers.

# %%
# Write your code here

# %% [markdown]
# ## Question 24
#
# Print all elements from a list using loop.

# %%
# Write your code here

# %% [markdown]
# ## Question 25
#
# Count vowels in a string using loop.

# %%
# Write your code here

# %% [markdown]
# ## Question 26
#
# Print star pattern triangle.

# %%
# Write your code here

# %% [markdown]
# ## Question 27
#
# Reverse a string using loop.

# %%
# Write your code here

# %% [markdown]
# ## Question 28
#
# Find factorial of a number using loop.

# %%
# Write your code here

# %% [markdown]
# # Functions Questions

# %% [markdown]
# ## Question 29
#
# Create function to add two numbers.

# %%
# Write your code here

# %% [markdown]
# ## Question 30
#
# Create function to find square of a number.

# %%
# Write your code here

# %% [markdown]
# ## Question 31
#
# Create function to check even or odd.

# %%
# Write your code here

# %% [markdown]
# ## Question 32
#
# Create function to find largest among three numbers.

# %%
# Write your code here

# %% [markdown]
# ## Question 33
#
# Create function to calculate simple interest.

# %%
# Write your code here

# %% [markdown]
# ## Question 34
#
# Create function to count vowels in string.

# %%
# Write your code here

# %% [markdown]
# ## Question 35
#
# Create function to calculate factorial.

# %%
# Write your code here

# %% [markdown]
# # User Defined Functions Questions

# %% [markdown]
# ## Question 36
#
# Create user defined function for calculator operations.

# %%
# Write your code here

# %% [markdown]
# ## Question 37
#
# Create function to print student details.

# %%
# Write your code here

# %% [markdown]
# ## Question 38
#
# Create function to return maximum number from list.

# %%
# Write your code here

# %% [markdown]
# ## Question 39
#
# Create function to check palindrome.

# %%
# Write your code here

# %% [markdown]
# ## Question 40
#
# Create function to count words in sentence.

# %%
# Write your code here

# %% [markdown]
# ## Question 41
#
# Create function to generate multiplication table.

# %%
# Write your code here

# %% [markdown]
# # Lambda Function Questions

# %% [markdown]
# ## Question 42
#
# Create lambda function to add two numbers.

# %%
# Write your code here

# %% [markdown]
# ## Question 43
#
# Create lambda function to find square of number.

# %%
# Write your code here

# %% [markdown]
# ## Question 44
#
# Use lambda with map() to double list values.

# %%
# Write your code here

# %% [markdown]
# ## Question 45
#
# Use lambda with filter() to find even numbers.

# %%
# Write your code here

# %% [markdown]
# ## Question 46
#
# Use lambda with sorted() to sort list.

# %%
# Write your code here

# %% [markdown]
# ## Question 47
#
# Create lambda function to find maximum of two numbers.

# %%
# Write your code here

# %% [markdown]
# # Mini Practice Programs

# %% [markdown]
# ## Question 48
#
# Student grading system

# %%
# Write your code here

# %% [markdown]
# ## Question 49
#
# ATM PIN validation

# %%
# Write your code here

# %% [markdown]
# ## Question 50
#
# Simple calculator

# %%
# Write your code here

# %% [markdown]
# ## Question 51
#
# Employee salary calculation

# %%
# Write your code here

# %% [markdown]
# ## Question 52
#
# Number guessing game

# %%
# Write your code here

# %% [markdown]
# ## Question 53
#
# Login validation system

# %%
# Write your code here

# %% [markdown]
# ## Question 54
#
# Shopping bill generator

# %%
# Write your code here

# %% [markdown]
# ## Question 55
#
# Bank balance checker

# %%
# Write your code here

# %% [markdown]
# # Bonus Challenges
#
# 1. Create menu driven calculator using loops and functions.
# 2. Create student result system using dictionary and functions.
# 3. Create grocery billing system.
# 4. Create login system with 3 attempts using while loop.
# 5. Create pattern printing using nested loops.
#
# ---
#
# # Instructions for Students
#
# - Try solving without copying.
# - Practice syntax properly.
# - Use meaningful variable names.
# - Run each cell after writing code.
# - Ask doubts wherever required.
#
# Happy Coding 🚀
